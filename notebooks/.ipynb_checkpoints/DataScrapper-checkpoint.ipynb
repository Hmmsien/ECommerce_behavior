# %% [markdown]
# ## Data Scrapper.
#
# The idea of this project is to have something that is able to:
#
# 1. Given an input of parameters e.g. category_code, brand (electronics, smartphone, xiaomi)
# 2. be able to fetch images (the first one) on google images
# 3. And post them to x database.

# %%
list_search = ["electronics, smartphone, xiaomi"]

# %%
from bs4 import BeautifulSoup
from PIL import Image
import requests
from io import BytesIO
import IPython.display as Disp
import pandas as pd
import numpy as np

# %%
def get_google_img(query):
    """
    gets a link to the first google image search result
    :param query: search query string
    :result: url string to first result
    """
    url = 'https://www.google.com/search?hl=jp&q=' + query + '&btnG=Google+Search&tbs=0&safe=off&tbm=isch'
    headers={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}

    html = requests.get(url, headers=headers).text

    soup = BeautifulSoup(html, 'html.parser')
    image = soup.find("img",{"class":"yWs4tf"})
#     print(image)

    if not image:
        return 
    return image['src']

# %%
# query = input("search term\n")
print(get_google_img("banana") or "no image found")
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQkixelwO2Hk4OJw0xh4HT79G9QjL_CRfOCHNXFYouRYYk5gzsJ_sfZ4P5E8g&s

# %%
from PIL import Image, ImageDraw


def searchFromList(list_search):
    for imgq in list_search:
        print(f"Searching: {imgq}")
        imgsrc = get_google_img(imgq)
        response = requests.get(imgsrc)
        img = Image.open(BytesIO(response.content))
        img.save(+".jpg")

# %% [markdown]
# ## Finding the unique
#
# Find unique datasets available

# %%
ROW_CATEGORY_CODE = "category_code"
ROW_BRAND = "brand"
ROW_NAME="product_name"
ROW_PRODUCT_ID = "product_id"
ROW_COUNT = "count"
ROW_EVENT = "event_type"
ROW_TIME = "event_time"
ROW_SESSION = "user_session"

# %%
df = pd.read_csv('data/2019-Oct.csv',nrows = 1000000)

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
ROW_CATEGORY_CODE = "category_code"
ROW_BRAND = "brand"
ROW_NAME="product_name"
ROW_PRODUCT_ID = "product_id"
ROW_COUNT = "count"
ROW_EVENT = "event_type"
ROW_TIME = "event_time"
ROW_SESSION = "user_session"

# %%
df[ROW_CATEGORY_CODE] = df[ROW_CATEGORY_CODE].astype(str)
df[ROW_BRAND] = df[ROW_BRAND].astype(str)

# %%
def create_name(dfrow):
    return returnSpaceForNan(dfrow[ROW_CATEGORY_CODE]) + " "+ returnSpaceForNan(dfrow[ROW_BRAND])

def returnSpaceForNan(field):
    return field if field != "nan" else ""

# %%
df[ROW_NAME] = df.apply(create_name, axis=1)

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  nan  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       nan   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session  \
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# ...

# %%
gb_count = df.groupby(ROW_PRODUCT_ID)[ROW_NAME].agg(["count"])

# %%
gb_count.head()
# Out:
#             count
# product_id
# 1001588        54
# 1002042         7
# 1002062        12
# 1002098       128
# 1002099       698

# %%
gb_count.reset_index(ROW_PRODUCT_ID)
# Out:
#        product_id  count
# 0         1001588     54
# 1         1002042      7
# 2         1002062     12
# 3         1002098    128
# 4         1002099    698
# ...           ...    ...
# 63317    53900011      2
# 63318    53900012     40
# 63319    53900014      2
# 63320    53900016      1
# 63321    53900017      2
#
# [63322 rows x 2 columns]

# %%
products = df.drop_duplicates(ROW_NAME)

# %%
products = products.merge(gb_count,how="left" , on=ROW_PRODUCT_ID)

# %%
products = products.sort_values(ROW_COUNT, ascending=False)

# %%
products.head()
# Out:
#      product_id          category_id                category_code   brand  \
# 70      5100816  2053013553375346967                          nan  xiaomi
# 19      1004739  2053013555631882655       electronics.smartphone  xiaomi
# 41      4804295  2053013554658804075  electronics.audio.headphone  xiaomi
# 80      1004838  2053013555631882655       electronics.smartphone    oppo
# 131     4804055  2053013554658804075  electronics.audio.headphone   apple
#
#       price    user_id                        product_name  count
# 70    29.51  515755304                              xiaomi   4736
# 19   197.55  519530528       electronics.smartphone xiaomi   4286
# 41    23.13  541366014  electronics.audio.headphone xiaomi   3409
# 80   179.38  552552067         electronics.smartphone oppo   2517
# 131  189.91  524601178   electronics.audio.headphone apple   2457

# %%
columns_to_drop = [ROW_EVENT, ROW_TIME, ROW_SESSION]

# %%
products = products.drop(columns=columns_to_drop)
products.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-504a74276df0> in <module>
# ----> 1 products = products.drop(columns=columns_to_drop)
#       2 products.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
imagesSearched = {}
error_ids = []
images = []
len(products)
# Out:
# 4052

# %%
products[ROW_NAME] = products[ROW_NAME].astype(str) 
loopProductsImages(products.head())
print(imagesSearched)
print(error_ids)
print(images)
# Out:
# 1/5 Search:  xiaomi, saving at: 5100816
# 2/5 Search: electronics.smartphone xiaomi, saving at: 1004739
# 3/5 Search: electronics.audio.headphone xiaomi, saving at: 4804295
# 4/5 Search: electronics.smartphone oppo, saving at: 1004838
# 5/5 Search: electronics.audio.headphone apple, saving at: 4804055
# {5100816: 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR4LZaaNf05pdgZyRorLVoSdXL4mlLhTQgKa4hs-OQeMCFIzsHAp3HSFWYYvwU&s', 1004739: 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQoe5hKUEZUHYd5rW5YOEgn-Nzo_eYJYFfagtGuoTjoSJsnOl4tx7TffHHSTpI&s', 4804295: 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRT259GmuS3DOBHQO4V9_izfoCBSnXQYCF4sNrN-3Lbl06wjEp3SbYiDFhMNNI&s', 1004838: 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgITS-k210utXRjRLbIYqw7uJklE4rRPF1IHajum-aTcZuiVPBmJjlhtb7VQ&s', 4804055: 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRd-_i8EJhDEC0b-MvQUXvfSYBAncpls8n8SbQOs7BgjXeaCnw_WSNXxtxkidI&s'}
# [5100816]
# ...

# %%
def loopProductsImages(df):
    sizedf = len(df)
    idx = 0
    for index, dfrow in df.iterrows():
        idx+=1
        print(f"{idx}/{sizedf} Search: {dfrow[ROW_NAME]}, saving at: {dfrow[ROW_PRODUCT_ID]}")
        try:
            imgq = dfrow[ROW_NAME]

            imgsrc = get_google_img(imgq)
            
            imagesSearched[dfrow[ROW_PRODUCT_ID]] = imgsrc
            images.append(imgsrc)
            response = requests.get(imgsrc)
            
            img = Image.open(BytesIO(response.content))
            img.save("data/images/"+str(dfrow[ROW_PRODUCT_ID])+".jpg")
            
        except Exception as e:
            
            print(f"Error at: {idx}/{sizedf} Search: {dfrow[ROW_NAME]}, saving at: {dfrow[ROW_PRODUCT_ID]}")
            error_ids.append(dfrow[ROW_PRODUCT_ID])
            images.append("")

# %%
TARGET_PRODUCTS_FILE="dist-data/products.csv"

# %%
products[ROW_NAME] = products[ROW_NAME].astype(str) 
loopProductsImages(products)
print(imagesSearched)
print(error_ids)
print(images)
# Out:
# 1/4052 Search:  xiaomi, saving at: 5100816
# 2/4052 Search: electronics.smartphone xiaomi, saving at: 1004739
# 3/4052 Search: electronics.audio.headphone xiaomi, saving at: 4804295
# 4/4052 Search: electronics.smartphone oppo, saving at: 1004838
# 5/4052 Search: electronics.audio.headphone apple, saving at: 4804055
# 6/4052 Search: electronics.video.tv artel, saving at: 1801766
# 7/4052 Search: electronics.video.tv samsung, saving at: 1801690
# 8/4052 Search: electronics.smartphone apple, saving at: 1004237
# 9/4052 Search: appliances.kitchen.washer indesit, saving at: 3600163
# 10/4052 Search:  stels, saving at: 22700129
# 11/4052 Search: computers.notebook acer, saving at: 1307073
# 12/4052 Search:  force, saving at: 22700084
# 13/4052 Search: auto.accessories.player jvc, saving at: 5700619
# 14/4052 Search: electronics.audio.headphone elari, saving at: 4804409
# 15/4052 Search: computers.notebook lenovo, saving at: 1307067
# ...

# %%
# append category_code and brand and then group them by that

df["item_title"] = df["category_code"] + " " + df["brand"]
df.head(1)
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
#
#             category_code   brand   price    user_id  \
# 0  electronics.smartphone  xiaomi  489.07  520088904
#
#                            user_session                     item_title
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33  electronics.smartphone xiaomi

# %%
gb = df.groupby("item_title")
# gb["item_title"].count()
listitems = gb["item_title"].head()
listitems.iloc[:10]
# Out:
# 0             electronics.smartphone xiaomi
# 1          appliances.sewing_machine janome
# 3              appliances.kitchen.washer lg
# 4             electronics.smartphone xiaomi
# 5                     computers.notebook hp
# 6                     computers.notebook hp
# 9              electronics.smartphone apple
# 14    appliances.kitchen.dishwasher samsung
# 18            electronics.smartphone huawei
# 19                    computers.notebook hp
# Name: item_title, dtype: object

# %% [markdown]
# ## Downloading the first 10 images

# %%
def download_images(list_search):
    for imgq in list_search:
        print(f"Searching: {imgq}")
        imgsrc = get_google_img(imgq)
        response = requests.get(imgsrc)
        img = Image.open(BytesIO(response.content))
        name = imgq
        name = name.replace(" ", "-")
        file_dir = "data/images/"
        img.save(f"{file_dir+name}.jpg")

# %%
download_images(list(listitems)[:10])
# Out:
# Searching: electronics.smartphone xiaomi
# Searching: appliances.sewing_machine janome
# Searching: appliances.kitchen.washer lg
# Searching: electronics.smartphone xiaomi
# Searching: computers.notebook hp
# Searching: computers.notebook hp
# Searching: electronics.smartphone apple
# Searching: appliances.kitchen.dishwasher samsung
# Searching: electronics.smartphone huawei
# Searching: computers.notebook hp

# %% [markdown]
# ## Uploading the first 10 images to the API

# %%
## Try first uploading one image to the ecommerce API
